# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
datasets=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
datasets
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
datasets.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=datasets[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dependent=datasets[['charges']]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid = {'criterion':['squared_error','absolute_error','friedman_mse','poisson'],'max_features':['sqrt','log2'],'n_estimators':[10,100,500]}

grid = GridSearchCV(RandomForestRegressor(),param_grid,refit=True, verbose=3, n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Users\ping2\anaconda3\Lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 100, 500]},
#              verbose=3)

# %%
re = grid.cv_results_
print("The R Score value for the best parameter {}".format(grid.best_params_))
# Out:
# The R Score value for the best parameter {'criterion': 'poisson', 'max_features': 'sqrt', 'n_estimators': 500}

# %%
table = pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.166137      0.014677         0.020952        0.006085
# 1        1.533539      0.074423         0.098309        0.015783
# 2        9.766612      1.796944         0.347137        0.082673
# 3        0.177278      0.019995         0.026981        0.005491
# 4        1.784257      0.262279         0.145222        0.105987
# 5        9.210673      1.714523         0.312739        0.165528
# 6        0.776605      0.155040         0.039899        0.028086
# 7        4.239333      0.424584         0.063994        0.033832
# 8       20.919527      3.018527         0.282809        0.270559
# 9        0.572345      0.050227         0.036653        0.010545
# 10       5.445632      1.615899         0.069440        0.037040
# 11      13.736984      2.552037         0.137470        0.017096
# 12       0.097468      0.003388         0.016411        0.006199
# ...

# %%
age = int(input("Age:"))
bmi = float(input("BMI:"))
children = int(input("Children:"))
sex_male = int(input("Sex Male 0 or 1:"))
smoker_yes = int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 33
# BMI: 44
# Children: 2
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 1

# %%
Future_Prediction = grid.predict([[age,bmi,children,sex_male,smoker_yes]])
print("Future_Prediction ={}".format(Future_Prediction))
# Out:
# Future_Prediction =[41088.18492256]
# C:\Users\ping2\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
