# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
datasets=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
datasets
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
datasets.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=datasets[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dependent=datasets[['charges']]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':['squared_error','absolute_error','friedman_mse','poisson'],'max_features':['sqrt','log2'],'splitter':['best','random']}

grid = GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True, verbose=3, n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re = grid.cv_results_
print("The R Score value for the best parameter {}".format(grid.best_params_))
# Out:
# The R Score value for the best parameter {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'splitter': 'best'}

# %%
table = pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.069657      0.021817         0.026960        0.012509
# 1        0.019974      0.009143         0.018472        0.005834
# 2        0.031267      0.006223         0.020124        0.005280
# 3        0.020919      0.007450         0.014680        0.004389
# 4        0.150058      0.014667         0.041916        0.023755
# 5        0.141698      0.063552         0.014792        0.007746
# 6        0.118606      0.023947         0.016402        0.005544
# 7        0.186154      0.047039         0.026575        0.011922
# 8        0.045396      0.005687         0.031004        0.016390
# 9        0.025729      0.010090         0.016893        0.005803
# 10       0.035045      0.003642         0.023959        0.006077
# 11       0.057885      0.015085         0.033268        0.014496
# 12       0.050272      0.024843         0.018175        0.005514
# 13       0.029812      0.003747         0.017863        0.006992
# 14       0.020904      0.004561         0.008577        0.001096
# 15       0.022704      0.003292         0.009876        0.002425
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4   absolute_error               sqrt           best
# 5   absolute_error               sqrt         random
# 6   absolute_error               log2           best
# 7   absolute_error               log2         random
# 8     friedman_mse               sqrt           best
# 9     friedman_mse               sqrt         random
# 10    friedman_mse               log2           best
# 11    friedman_mse               log2         random
# 12         poisson               sqrt           best
# 13         poisson               sqrt         random
# 14         poisson               log2           best
# 15         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.680689
# 1   {'criterion': 'squared_error', 'max_features':...           0.724912
# 2   {'criterion': 'squared_error', 'max_features':...           0.659738
# 3   {'criterion': 'squared_error', 'max_features':...           0.710709
# 4   {'criterion': 'absolute_error', 'max_features'...           0.674036
# 5   {'criterion': 'absolute_error', 'max_features'...           0.675030
# 6   {'criterion': 'absolute_error', 'max_features'...           0.640786
# 7   {'criterion': 'absolute_error', 'max_features'...           0.698907
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.795676
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.638154
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.662127
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.674072
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.733428
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.649560
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.735395
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.697394
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.659202           0.734883           0.726705
# 1            0.556176           0.709625           0.666741
# 2            0.629318           0.715421           0.692039
# 3            0.463769           0.698410           0.658797
# 4            0.659754           0.690594           0.729493
# 5            0.574199           0.463631           0.674537
# 6            0.619522           0.668686           0.543894
# 7            0.544586           0.695159           0.617760
# 8            0.626735           0.706247           0.728774
# 9            0.666474           0.636470           0.674052
# 10           0.570118           0.651137           0.734858
# 11           0.570012           0.773737           0.673042
# 12           0.659978           0.694753           0.690640
# 13           0.614138           0.605307           0.579886
# 14           0.596226           0.732434           0.667800
# 15           0.600336           0.656208           0.549814
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.700870         0.700470        0.028167                3
# 1            0.699262         0.671343        0.060662                7
# 2            0.584540         0.656211        0.046178               10
# 3            0.646289         0.635595        0.089179               14
# 4            0.770605         0.704896        0.040293                2
# 5            0.627401         0.602960        0.078936               16
# 6            0.751884         0.644954        0.067638               12
# 7            0.709819         0.653246        0.063417               11
# 8            0.755316         0.722550        0.056402                1
# 9            0.728983         0.668827        0.033584                8
# 10           0.718179         0.667284        0.058112                9
# 11           0.676674         0.673507        0.064448                6
# 12           0.706049         0.696970        0.023770                5
# 13           0.765721         0.642923        0.065331               13
# 14           0.760528         0.698477        0.059603                4
# 15           0.632667         0.627284        0.050018               15

# %%
age = int(input("Age:"))
bmi = float(input("BMI:"))
children = int(input("Children:"))
sex_male = int(input("Sex Male 0 or 1:"))
smoker_yes = int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 33
# BMI: 35
# Children: 2
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 0

# %%
Future_Prediction = grid.predict([[age,bmi,children,sex_male,smoker_yes]])
print("Future_Prediction ={}".format(Future_Prediction))
# Out:
# Future_Prediction =[46661.4424]
